# %%
import pandas as pd
from matplotlib import pyplot as plt
import numbers

# %%
import utils.visualisation_tb as vis
import utils.mining_data_tb as md

# %%
vis.time_consuming()

# %%
emu_gdp_df, esp_gdp_df, deu_gdp_df, fra_gdp_df, gbr_gdp_df, prt_gdp_df = md.all_gdp_per_capita()
# Out:
# b'Skipping line 21: expected 32 fields, saw 33\nSkipping line 40: expected 32 fields, saw 33\nSkipping line 41: expected 32 fields, saw 33\nSkipping line 63: expected 32 fields, saw 33\nSkipping line 75: expected 32 fields, saw 33\nSkipping line 82: expected 32 fields, saw 33\nSkipping line 92: expected 32 fields, saw 33\nSkipping line 108: expected 32 fields, saw 33\nSkipping line 122: expected 32 fields, saw 33\nSkipping line 142: expected 32 fields, saw 33\nSkipping line 244: expected 32 fields, saw 33\nSkipping line 250: expected 32 fields, saw 33\n'

# %%
vis.eu_gdp_plot(var_1=emu_gdp_df)

# %%
vis.all_eu_gdp_plot(var_1=emu_gdp_df, var_2=esp_gdp_df, var_3=deu_gdp_df, var_4=fra_gdp_df, var_5=gbr_gdp_df, var_6=prt_gdp_df)

# %%
vis.histogram_gdp_eu(var_1=emu_gdp_df)

# %%
eu_ir_df, es_ir_df, de_ir_df, fr_ir_df, uk_ir_df, pt_ir_df= md.all_inflation_rates()

# %%
vis.eu_ir_plot(var_1=eu_ir_df)

# %%
vis.all_eu_ir_plot(var_1=eu_ir_df, var_2=es_ir_df, var_3=de_ir_df, var_4=fr_ir_df, var_5=uk_ir_df, var_6=pt_ir_df)

# %%
vis.histogram_ir_eu(var_1=eu_ir_df)

# %%
eu_ur_df, es_ur_df, de_ur_df, fr_ur_df, uk_ur_df, pt_ur_df=md.unemployment()

# %%
vis.eu_unemployment_plot(var_1=eu_ur_df)

# %%
eu_ur_df_2008_2019= md.unemployment_2008_2019()
year = {'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]}
year_df=pd.DataFrame(year)

# %%
vis.eu_unemployment_plot_2008_2019(var_1=eu_ur_df_2008_2019)

# %%
vis.all_eu_unemployment_plot(var_1=eu_ur_df, var_2=es_ur_df, var_3=de_ur_df, var_4=fr_ur_df, var_5=uk_ur_df, var_6=pt_ur_df)

# %%
vis.histogram_ur_eu(var_1=eu_ur_df)

# %%
vis.ir_and_ur(var_1=year_df, var_2=eu_ir_df, var_3=eu_ur_df_2008_2019)

# %%
eu_x_box_sales, eu_play_station_sales, eu_nintendo_sales=md.all_videogames()

# %%
vis.histogram_xbox(var_1=eu_x_box_sales)

# %%
vis.x_box_sales_eu(var_1=eu_x_box_sales)

# %%
nintendo_sales=md.nintendo_correlation_matrix()

# %%
vis.correlation_matrix_nintendo(var_1=nintendo_sales)

# %%
vis.histogram_play_station(var_1=eu_play_station_sales)

# %%
vis.play_station_sales_eu(var_1=eu_play_station_sales)

# %%
vis.histogram_nintendo(var_1=eu_nintendo_sales)

# %%
vis.nintendo_sales_eu(var_1=eu_nintendo_sales)

# %%
vis.video_game_sales_eu(var_1=eu_nintendo_sales, var_2=eu_play_station_sales, var_3=eu_x_box_sales)

# %%
eu_x_box_sales, eu_play_station_sales, eu_nintendo_sales=md.all_videogames_2008_2017()

# %%
vis.video_game_sales_eu_2008_2017(var_1=eu_nintendo_sales, var_2=eu_play_station_sales, var_3=eu_x_box_sales)

# %%
nintendo_percentage, play_station_percentage, x_box_percentage=md.all_videogames_pc()

# %%
vis.eu_console_marketshare(var_1=nintendo_percentage, var_2=play_station_percentage, var_3=x_box_percentage)
